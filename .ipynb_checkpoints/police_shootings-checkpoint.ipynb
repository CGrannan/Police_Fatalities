# %% [markdown]
# # Introduction
# For this project I am looking at statistics of police related fatalities from 2015-present. I am curious to see how these statistics have changed over time and whether there are statistical differences between groups. To start out, I will be loading in some key libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline
import datetime
import gmaps
import os

# %% [markdown]
# # Loading and Cleaning Data
# ### Load in data from 2015-2020
#
# I'm going to be working with and combining multiple datasets for this project. I will start by looking at a dataset of police fatalities from 2015 to 2020. I will load in the data, look for missing values, and dig into some of the columns to get a general sense of how the dataset is structured.

# %%
present_data = pd.read_csv('fatal-police-shootings-data.csv')
present_data.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
present_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6005 entries, 0 to 6004
# Data columns (total 17 columns):
# id                         6005 non-null int64
# name                       5787 non-null object
# date                       6005 non-null object
# manner_of_death            6005 non-null object
# armed                      5795 non-null object
# age                        5740 non-null float64
# gender                     6004 non-null object
# race                       5400 non-null object
# city                       6005 non-null object
# state                      6005 non-null object
# signs_of_mental_illness    6005 non-null bool
# threat_level               6005 non-null object
# flee                       5666 non-null object
# body_camera                6005 non-null bool
# longitude                  5711 non-null float64
# latitude                   5711 non-null float64
# is_geocoding_exact         6005 non-null bool
# ...

# %% [markdown]
# From here, I will be looking at various columns to look at what values our data contains and get a general idea of distributions.

# %%
present_data.date = pd.to_datetime(present_data.date)
present_data.head()
# Out:
#    id                name       date   manner_of_death       armed   age  \
# 0   3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
present_data.body_camera.value_counts()
# Out:
# False    5250
# True      755
# Name: body_camera, dtype: int64

# %%
present_data.gender.value_counts()
# Out:
# M    5740
# F     264
# Name: gender, dtype: int64

# %%
present_data.city.value_counts()[:10]
# Out:
# Los Angeles    91
# Phoenix        88
# Houston        64
# Las Vegas      52
# San Antonio    50
# Chicago        41
# Albuquerque    40
# Columbus       40
# Kansas City    36
# Denver         36
# Name: city, dtype: int64

# %%
present_data.armed.value_counts()[:10]
# Out:
# gun               3425
# knife              883
# unarmed            384
# toy weapon         201
# vehicle            190
# undetermined       168
# unknown weapon      87
# machete             49
# Taser               27
# ax                  24
# Name: armed, dtype: int64

# %%
present_data.race.value_counts()
# Out:
# W    2742
# B    1428
# H    1005
# A      96
# N      82
# O      47
# Name: race, dtype: int64

# %%
present_data.manner_of_death.value_counts()
# Out:
# shot                5703
# shot and Tasered     302
# Name: manner_of_death, dtype: int64

# %%
present_data.threat_level.value_counts()
# Out:
# attack          3883
# other           1863
# undetermined     259
# Name: threat_level, dtype: int64

# %%
present_data.flee.value_counts()
# Out:
# Not fleeing    3703
# Car             990
# Foot            775
# Other           198
# Name: flee, dtype: int64

# %%
present_data.is_geocoding_exact.value_counts()
# Out:
# True     5997
# False       8
# Name: is_geocoding_exact, dtype: int64

# %% [markdown]
# ### Loading in data from 2000-2016
#
# Next up, we will be loading in a dataset of police fatalities from 2000-2016. Again we will look for missing values and look at some of our columns to get an idea of the second dataset.

# %%
older_data = pd.read_csv('Old Police Fatalities.csv', encoding = "ISO-8859-1")
older_data.head()
# Out:
#    UID                     Name   Age  Gender   Race       Date         City  \
# 0  133            Karen O. Chin  44.0  Female  Asian   5/4/2000      Alameda
# 1  169     Chyraphone Komvongsa  26.0    Male  Asian   6/2/2000       Fresno
# 2  257            Ming Chinh Ly  36.0    Male  Asian  8/13/2000     Rosemead
# 3  483            Kinh Quoc Dao  29.0    Male  Asian   2/9/2001  Valley Glen
# 4  655  Vanpaseuth Phaisouphanh  25.0    Male  Asian  6/10/2001    Riverside
#
#   State Manner_of_death  Armed  Mental_illness   Flee
# 0    CA            Shot    NaN           False  False
# 1    CA            Shot    NaN           False  False
# 2    CA            Shot    Gun           False  False
# 3    CA            Shot    Gun           False  False
# 4    CA            Shot  Knife           False  False

# %%
older_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 12 columns):
# UID                12491 non-null int64
# Name               12491 non-null object
# Age                12258 non-null float64
# Gender             12483 non-null object
# Race               8526 non-null object
# Date               12491 non-null object
# City               12487 non-null object
# State              12491 non-null object
# Manner_of_death    12491 non-null object
# Armed              6814 non-null object
# Mental_illness     12491 non-null bool
# Flee               12491 non-null bool
# dtypes: bool(2), float64(1), int64(1), object(8)
# memory usage: 1000.3+ KB

# %%
older_data.Date = pd.to_datetime(older_data.Date)
older_data.head()
# Out:
#    UID                     Name   Age  Gender   Race       Date         City  \
# 0  133            Karen O. Chin  44.0  Female  Asian 2000-05-04      Alameda
# 1  169     Chyraphone Komvongsa  26.0    Male  Asian 2000-06-02       Fresno
# 2  257            Ming Chinh Ly  36.0    Male  Asian 2000-08-13     Rosemead
# 3  483            Kinh Quoc Dao  29.0    Male  Asian 2001-02-09  Valley Glen
# 4  655  Vanpaseuth Phaisouphanh  25.0    Male  Asian 2001-06-10    Riverside
#
#   State Manner_of_death  Armed  Mental_illness   Flee
# 0    CA            Shot    NaN           False  False
# 1    CA            Shot    NaN           False  False
# 2    CA            Shot    Gun           False  False
# 3    CA            Shot    Gun           False  False
# 4    CA            Shot  Knife           False  False

# %%
older_data = older_data[['UID', 'Name', 'Date', 'Manner_of_death', 'Armed', 'Age', 'Gender', 'Race', 'City', 'State', 'Mental_illness', 'Flee']]
older_data.columns = ['id','name', 'date', 'manner_of_death', 'armed', 'age', 'gender', 'race', 'city', 'state', 'signs_of_mental_illness', 'flee']
older_data.head()
# Out:
#     id                     name       date manner_of_death  armed   age  \
# 0  133            Karen O. Chin 2000-05-04            Shot    NaN  44.0
# 1  169     Chyraphone Komvongsa 2000-06-02            Shot    NaN  26.0
# 2  257            Ming Chinh Ly 2000-08-13            Shot    Gun  36.0
# 3  483            Kinh Quoc Dao 2001-02-09            Shot    Gun  29.0
# 4  655  Vanpaseuth Phaisouphanh 2001-06-10            Shot  Knife  25.0
#
#    gender   race         city state  signs_of_mental_illness   flee
# 0  Female  Asian      Alameda    CA                    False  False
# 1    Male  Asian       Fresno    CA                    False  False
# 2    Male  Asian     Rosemead    CA                    False  False
# 3    Male  Asian  Valley Glen    CA                    False  False
# 4    Male  Asian    Riverside    CA                    False  False

# %%
older_data.gender.value_counts()
# Out:
# Male      11870
# Female      613
# Name: gender, dtype: int64

# %%
older_data.city.value_counts()[:10]
# Out:
# Los Angeles     297
# Houston         247
# Phoenix         177
# Chicago         175
# Las Vegas       153
# San Diego       104
# Miami           104
# Dallas           99
# Tucson           94
# Jacksonville     93
# Name: city, dtype: int64

# %%
older_data.armed.value_counts()[:10]
# Out:
# Gun               4703
# Knife             1361
# Unarmed            400
# Vehicle            111
# Toy Weapon          69
# Toy weapon          29
# Machete             16
# Unknown Weapon      15
# Sword                8
# Hammer               7
# Name: armed, dtype: int64

# %%
older_data.race.value_counts()
# Out:
# White       3855
# Black       2536
# Hispanic    1784
# Asian        173
# Native       130
# Other         48
# Name: race, dtype: int64

# %%
older_data.manner_of_death.value_counts()
# Out:
# Shot                11800
# Tasered               542
# Shot and Tasered      120
# Other                  29
# Name: manner_of_death, dtype: int64

# %%
older_data = older_data[(older_data.manner_of_death == "Shot") | (older_data.manner_of_death == "Shot and Tasered")]
older_data.manner_of_death.value_counts()
# Out:
# Shot                11800
# Shot and Tasered      120
# Name: manner_of_death, dtype: int64

# %%
older_data.flee.value_counts()
# Out:
# False    11360
# True       560
# Name: flee, dtype: int64

# %%
older_data.signs_of_mental_illness.value_counts()
# Out:
# False    9546
# True     2374
# Name: signs_of_mental_illness, dtype: int64

# %%
older_data.gender = older_data.gender.str[:1]
older_data.race = older_data.race.str[:1]
older_data.armed = older_data.armed.str.lower()
older_data.manner_of_death = older_data.manner_of_death.str.lower()
older_data.flee = older_data.flee.map({True:'Fleeing', False:'Not fleeing'})
older_data.head()
# Out:
#     id                     name       date manner_of_death  armed   age  \
# 0  133            Karen O. Chin 2000-05-04            shot    NaN  44.0
# 1  169     Chyraphone Komvongsa 2000-06-02            shot    NaN  26.0
# 2  257            Ming Chinh Ly 2000-08-13            shot    gun  36.0
# 3  483            Kinh Quoc Dao 2001-02-09            shot    gun  29.0
# 4  655  Vanpaseuth Phaisouphanh 2001-06-10            shot  knife  25.0
#
#   gender race         city state  signs_of_mental_illness         flee
# 0      F    A      Alameda    CA                    False  Not fleeing
# 1      M    A       Fresno    CA                    False  Not fleeing
# 2      M    A     Rosemead    CA                    False  Not fleeing
# 3      M    A  Valley Glen    CA                    False  Not fleeing
# 4      M    A    Riverside    CA                    False  Not fleeing

# %%
present_for_combine = present_data[['name', 'date', 'manner_of_death', 'armed', 'age', 'gender', 'race', 'city', 'state', 'signs_of_mental_illness', 'flee']]
present_for_combine.flee = present_for_combine.flee.map({'Car':'Fleeing', 'Foot':'Fleeing', 'Other':'Fleeing','Not fleeing':'Not fleeing'})
present_for_combine.head()
# Out:
# /Users/rlathbury/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  signs_of_mental_illness         flee
# ...

# %%
print(len(present_data[(present_data.date >= '2015-01-01') & (present_data.date < '2017-01-01')]))
print(len(older_data[older_data.date >= '2015-01-01']))
# Out:
# 1955
# 3347

# %%
combined = pd.concat([present_for_combine, older_data.drop(['id'], axis=1)]).reset_index()
combined = combined[['name', 'date', 'manner_of_death', 'armed', 'age', 'gender', 'race', 'city', 'state', 'signs_of_mental_illness', 'flee']]
print(len(combined))
combined = combined.drop_duplicates()
print(len(combined))
combined.head()
# Out:
# 17925
# 16388
#                  name       date   manner_of_death       armed   age gender  \
# 0          Tim Elliot 2015-01-02              shot         gun  53.0      M
# 1    Lewis Lee Lembke 2015-01-02              shot         gun  47.0      M
# 2  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0      M
# 3     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0      M
# 4   Michael Rodriguez 2015-01-04              shot    nail gun  39.0      M
#
#   race           city state  signs_of_mental_illness         flee
# 0    A        Shelton    WA                     True  Not fleeing
# 1    W          Aloha    OR                    False  Not fleeing
# 2    H        Wichita    KS                    False  Not fleeing
# 3    W  San Francisco    CA                     True  Not fleeing
# 4    H          Evans    CO                    False  Not fleeing

# %% [markdown]
# ### Loading in Population Data
#
# Now I will load in some info on the general population. For this project I will be looking at data for the overall population estimates for the country and for each state from 2000-2020, as well as demographic breakdowns of race and gender for the country and for each state. We will be using this data to compare sample populations from our shooting data against the populations of the country and the states.

# %%
state_abbrev = {
    'United States': 'US',
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
pop_data2015 = pd.read_csv('population_data/2015.csv', header=2)
pop_data2015.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  192593600.0  37923800.0  55241300.0  16755300.0
# 1        Alabama    3131400.0   1251500.0    188000.0     55300.0
# 2         Alaska     435400.0     22900.0     47600.0     49000.0
# 3        Arizona    3714900.0    264200.0   2045900.0    207300.0
# 4       Arkansas    2106000.0    446400.0    204300.0     39000.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      1986900.0                                466400.0
# 1                        16300.0                                     NaN
# 2                        98700.0                                  2800.0
# 3                       270800.0                                  8900.0
# 4                        18000.0                                  6100.0
#
#          Total  Footnotes
# 0  312777900.0        1.0
# 1    4730100.0        NaN
# 2     707500.0        NaN
# ...

# %%
pop_data2016 = pd.read_csv('population_data/2016.csv', header=2)
pop_data2016.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  192537500.0  38081700.0  56144400.0  17004500.0
# 1        Alabama    3121800.0   1252500.0    194500.0     57600.0
# 2         Alaska     439200.0     20700.0     47800.0     42600.0
# 3        Arizona    3754900.0    270000.0   2087500.0    213600.0
# 4       Arkansas    2114900.0    441600.0    210000.0     39500.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2041500.0                                514600.0
# 1                        21400.0                                     NaN
# 2                       107200.0                                  8800.0
# 3                       266700.0                                 11600.0
# 4                        17300.0                                  7700.0
#
#          Total  Footnotes
# 0  314466400.0        1.0
# 1    4730100.0        NaN
# 2     714900.0        NaN
# ...

# %%
pop_data2017 = pd.read_csv('population_data/2017.csv', header=2)
pop_data2017.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  192336100.0  38408000.0  57560600.0  17651200.0
# 1        Alabama    3119100.0   1259900.0    195700.0     63800.0
# 2         Alaska     433000.0     18000.0     47400.0     46600.0
# 3        Arizona    3761600.0    270200.0   2143400.0    220300.0
# 4       Arkansas    2109200.0    434100.0    220300.0     48100.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2039400.0                                502500.0
# 1                        19800.0                                     NaN
# 2                        95500.0                                  6300.0
# 3                       261300.0                                 12500.0
# 4                        13500.0                                  7300.0
#
#          Total  Footnotes
# 0  317022500.0        1.0
# 1    4741400.0        NaN
# 2     710100.0        NaN
# ...

# %%
pop_data2018 = pd.read_csv('population_data/2018.csv', header=2)
pop_data2018.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  192117000.0  38655700.0  58483600.0  17844800.0
# 1        Alabama    3115600.0   1257300.0    204800.0     63800.0
# 2         Alaska     426100.0     20700.0     50200.0     43200.0
# 3        Arizona    3815100.0    297000.0   2213600.0    227200.0
# 4       Arkansas    2110400.0    436900.0    224900.0     44200.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2082800.0                                519500.0
# 1                        19000.0                                     NaN
# 2                       110300.0                                  7400.0
# 3                       271900.0                                 12000.0
# 4                        17000.0                                  8200.0
#
#          Total  Footnotes
# 0  318498500.0        1.0
# 1    4752600.0        NaN
# 2     709100.0        NaN
# ...

# %%
pop_data2019 = pd.read_csv('population_data/2019.csv', header=2)
pop_data2019.head()
# Out:
#         Location        White       Black    Hispanic       Asian  \
# 0  United States  191757100.0  38872200.0  59102900.0  18007200.0
# 1        Alabama    3117200.0   1263500.0    211700.0     65200.0
# 2         Alaska     421100.0     15200.0     48900.0     42000.0
# 3        Arizona    3843700.0    306600.0   2254800.0    231000.0
# 4       Arkansas    2108400.0    444200.0    226800.0     45500.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2125700.0                                528200.0
# 1                        18800.0                                     NaN
# 2                       106000.0                                 10400.0
# 3                       276100.0                                 12500.0
# 4                        16700.0                                 10800.0
#
#          Total  Footnotes
# 0  319249300.0        1.0
# 1    4767100.0        NaN
# 2     701700.0        NaN
# ...

# %%
year = 2015
for df in [pop_data2015, pop_data2016, pop_data2017, pop_data2018, pop_data2019]:
    df['Location'] = df['Location'].map(state_abbrev).fillna(df['Location'])
    df['Year'] = year
    year += 1
print(pop_data2019.head())
pop_data2015.head()
# Out:
# 2016
# 2017
# 2018
# 2019
# 2020
#   Location        White       Black    Hispanic       Asian  \
# 0       US  191757100.0  38872200.0  59102900.0  18007200.0
# 1       AL    3117200.0   1263500.0    211700.0     65200.0
# 2       AK     421100.0     15200.0     48900.0     42000.0
# 3       AZ    3843700.0    306600.0   2254800.0    231000.0
# 4       AR    2108400.0    444200.0    226800.0     45500.0
#
#    American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 0                      2125700.0                                528200.0
# 1                        18800.0                                     NaN
# 2                       106000.0                                 10400.0
# 3                       276100.0                                 12500.0
# 4                        16700.0                                 10800.0
#
#          Total  Footnotes  Year
# 0  319249300.0        1.0  2019
# 1    4767100.0        NaN  2019
# ...

# %%
pop_data = pd.concat([pop_data2015[:52], pop_data2016[:52], pop_data2017[:52], pop_data2018[:52], pop_data2019[:52]]).reset_index()
pop_data.drop(['index', 'Footnotes'], axis=1, inplace=True)
pop_data = pop_data.sort_values(['Location', 'Year'])
pop_data.head()
# Out:
#     Location     White    Black  Hispanic    Asian  \
# 2         AK  435400.0  22900.0   47600.0  49000.0
# 54        AK  439200.0  20700.0   47800.0  42600.0
# 106       AK  433000.0  18000.0   47400.0  46600.0
# 158       AK  426100.0  20700.0   50200.0  43200.0
# 210       AK  421100.0  15200.0   48900.0  42000.0
#
#      American Indian/Alaska Native  Native Hawaiian/Other Pacific Islander  \
# 2                          98700.0                                  2800.0
# 54                        107200.0                                  8800.0
# 106                        95500.0                                  6300.0
# 158                       110300.0                                  7400.0
# 210                       106000.0                                 10400.0
#
#         Total  Year
# 2    707500.0  2015
# 54   714900.0  2016
# 106  710100.0  2017
# 158  709100.0  2018
# 210  701700.0  2019

# %% [markdown]
# # EDA
#
# Now I will take a look at how our data shapes up. First up is the current shooting data. I will be looking at how the number of fatalities changes by state, by time, and by certain variables over time.

# %%
present_data.state.value_counts().plot(kind='bar', figsize=(20,10))
plt.title('Number of Fatalities by State')
plt.xlabel('State')
plt.ylabel('Number of Fatalities')
plt.show()

# %%
shot_tazed_data = present_data[present_data["manner_of_death"]!="shot"]
shot_tazed_data.state.value_counts().plot(kind='bar', figsize=(15,6))
plt.title('Number of Tazer Related Fatalities by State')
plt.xlabel('State')
plt.ylabel('Number of Fatalities')
plt.show()

# %%
shot_data = present_data[present_data["manner_of_death"]=="shot"]
heatmap_data = shot_data[['latitude', 'longitude']]
heatmap_data = heatmap_data.dropna()
heatmap_data.head()
# Out:
#    latitude  longitude
# 0    47.247   -123.122
# 1    45.487   -122.892
# 3    37.763   -122.422
# 4    40.384   -104.692
# 5    35.877    -97.423

# %%
heatmap_data2 = shot_tazed_data[['latitude', 'longitude']]
heatmap_data2 = heatmap_data2.dropna()
heatmap_data2.head()
# Out:
#     latitude  longitude
# 2     37.695    -97.281
# 10    37.930   -121.299
# 23    36.185   -115.116
# 38    37.588   -122.060
# 43    37.565    -82.921

# %%
# Creates a google maps oject with heat map overtop. Currently a bit buggy and runs slow. 
# Ongoing fix.

'''key = os.environ.get("gmapsapi")
gmaps.configure(api_key=key) 


heatmap_layer = gmaps.symbol_layer(heatmap_data, fill_color="red", stroke_color="red", scale=2)
heatmap_layer2 = gmaps.symbol_layer(heatmap_data2, fill_color="green", stroke_color="green", scale=2)
fig = gmaps.figure()
fig.add_layer(heatmap_layer)
fig.add_layer(heatmap_layer2)
fig'''
# Out:
# 'key = os.environ.get("gmapsapi")\ngmaps.configure(api_key=key) \n\n\nheatmap_layer = gmaps.symbol_layer(heatmap_data, fill_color="red", stroke_color="red", scale=2)\nheatmap_layer2 = gmaps.symbol_layer(heatmap_data2, fill_color="green", stroke_color="green", scale=2)\nfig = gmaps.figure()\nfig.add_layer(heatmap_layer)\nfig.add_layer(heatmap_layer2)\nfig'

# %% [markdown]
# Now let's look at how the data breaks down over time. We will look at total fatalities by month and by year

# %%
months = present_data.set_index(present_data.date)
months = months.resample('m', kind='period').count()['id']

fig, ax = plt.subplots()
ax = months.plot(kind='bar', figsize=(20, 8))

#Reduce x-axis clutter by limiting the number of x-ticks:
ticks = ax.get_xticks()
labels = ax.get_xticklabels()
n = len(ticks) // 25  # Show 25 ticks, every third one.
ax.set_xticks(ticks[::3]) 
ax.set_xticklabels(labels[::3])

plt.title('Monthly Number of Shootings')
plt.xlabel('Month')
plt.ylabel('Number of Shootings')
plt.show()

# %%
years = present_data.set_index(present_data.date)
years = years.resample('y', kind='period').count()['id']
years.plot(kind='bar', figsize=(20, 8))

plt.title('Number of Shootings By Year: 2015-2020')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %% [markdown]
# That is surprisingly consistent.
#
# Now I will check out how the numbers of shootings change yearly in respect to gender, race and state.

# %%
yearly_gender = present_data.groupby([present_data.date.dt.year, 'gender']).id.count()
yearly_gender.unstack().plot(figsize=(12,8))

plt.title('Number of Shootings Yearly By Gender: 2015-2020')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %%
yearly_race = present_data.groupby([present_data.date.dt.year, 'race']).id.count()
yearly_race.unstack().plot(figsize=(12,8))

plt.title('Number of Shootings Yearly By Race: 2015-2020')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %%
yearly_state = present_data.groupby([present_data.date.dt.year, 'state']).id.count()
yearly_state.unstack().plot(figsize=(20,10))

plt.title('Number of Shootings Yearly By State: 2015-2020')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %% [markdown]
# Now I will be looking at the same graphs for the older shooting data (2000-2016).

# %%
older_data.state.value_counts('normalize').plot(kind='bar', figsize=(20,10))
plt.title('Number of Fatalities by State')
plt.xlabel('State')
plt.ylabel('Number of Fatalities')
plt.show()

# %%
older_months = older_data.set_index(older_data.date)
older_months = older_months.resample('m', kind='period').count()['id']

fig, ax = plt.subplots()
ax = older_months.plot(kind='bar', figsize=(20, 12))

# Again reduce x-ticks to make graph legible
ticks = ax.get_xticks()
labels = ax.get_xticklabels()

ax.set_xticks(ticks[6::12])
ax.set_xticklabels(labels[6::12])

plt.title('Number of Shootings by Month: 2000-2016')
plt.xlabel('Month')
plt.ylabel('Number of Shootings')
plt.show()

# %%
older_years = older_data.set_index(older_data.date)
older_years = older_years.resample('y', kind='period').count()['id']

fig, ax = plt.subplots()
ax = older_years.plot(kind='bar', figsize=(20, 8))

plt.title('Number of Shootings by Year: 2000-2016')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %%
older_yearly_gender = older_data.groupby([older_data.date.dt.year, 'gender']).id.count()
older_yearly_gender.unstack().plot(figsize=(12,8))

plt.title('Number of Shootings Yearly By Gender: 2000-2016')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %%
older_yearly_race = older_data.groupby([older_data.date.dt.year, 'race']).id.count()
older_yearly_race.unstack().plot(figsize=(12,8))

plt.title('Number of Shootings Yearly By Race: 2000-2016')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %%
older_yearly_state = older_data.groupby([older_data.date.dt.year, 'state']).id.count()
older_yearly_state.unstack().plot(figsize=(20,18))

plt.title('Number of Shootings Yearly By State: 2000-2016')
plt.xlabel('Year')
plt.ylabel('Number of Shootings')
plt.show()

# %% [markdown]
# ## Analysis
